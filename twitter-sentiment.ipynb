# %%
import tweepy
from textblob import TextBlob, Word, Blobber
from textblob.classifiers import NaiveBayesClassifier
from textblob.taggers import NLTKTagger
import pandas as pd
import numpy as np      # For number computing


consumer_key ='HJr2LVulkmIlJiOJcnNpeshQT'
consumer_secret = 'EMSMVvQUeTvovzaTUaDrTgP4ONl3MWNr5Dj3bmfte9fLiVRN52'

access_token = '3220829192-U37nOKZ9x3jS2IZkmXB4zj7FHNxMNa1hFz31frN'
access_token_secret = '8HfC3LhIbbgXrnsSNbWnmmdA6FWhgRKbdK7IttpsfCu6R'

auth = tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)

api = tweepy.API(auth)

public_tweets = api.search('rafale')

for tweet in public_tweets:
    print(tweet.text)
    analysis = TextBlob(tweet.text)
    print(analysis.sentiment)
    
    
data = pd.DataFrame(data=[tweet.text for tweet in public_tweets], columns=['Tweets'])


data.head()
# Out:
# RT @adarshshastri: The way PM Modi &amp; his Govt has bulldozed &amp; transferred CBI Director Alok Verma shows their utter disregard for the Const…
# Sentiment(polarity=0.0, subjectivity=1.0)
# RT @theskindoctor13: How @narendramodi is facing media trial in #Rafale issue. https://t.co/2LoRxtTNqS
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @Pawankhera: Dear Einstein, if @narendramodi had not subverted the original MMRCA deal of 126 #Rafale jets, there would have been no nee…
# Sentiment(polarity=0.375, subjectivity=0.75)
# RT @astitvam: Not women now even children have started explaining @RahulGandhi about Rafale deal! https://t.co/TzHz8aSmLJ
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @nsitharaman: Thanks for posting this. My special thanks to this smart young lady (dear child, if affection permitted) for taking intere…
# Sentiment(polarity=0.21428571428571427, subjectivity=0.40285714285714286)
# National Burden.... useless ..
# 8 yrs proved ... https://t.co/n9tPswidm1
# ...
